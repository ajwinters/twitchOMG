# %%
import pandas as pd
import json

# %%
##Below pulls data as json might need to address the output file better
##curl -X --location --request GET "https://api.twitch.tv/helix/search/channels?query=mrmouton" --header "client-id: gp762nuuoqcoxypju8c569th9wz7q5" --header "Authorization: Bearer 636bomhe0i19hiu8sifssbpw1tqgi6" -o out.json

# %%
with open("out.json","r") as read_file:
    print("Read JSON file")
    student = json.load(read_file)

    #print("Before Pretty Printing JSON Data")
    #print(student)

    print("\n")

    PrettyJson = json.dumps(student, indent=4, separators=(',', ': '), sort_keys=True)
    print("Displaying Pretty Printed JSON Data")
    print(PrettyJson)
# Out:
# Read JSON file
#
#
# Displaying Pretty Printed JSON Data
# {
#     "data": [
#         {
#             "broadcaster_language": "en",
#             "display_name": "mrmouton",
#             "game_id": "23857",
#             "id": "45686481",
#             "is_live": true,
#             "started_at": "2020-11-22T12:22:36Z",
#             "tag_ids": [
#                 "6ea6bca4-4712-4ab9-a906-e3336a9d8039"
#             ],
#             "thumbnail_url": "https://static-cdn.jtvnw.net/jtv_user_pictures/faece39d-7e5d-4368-9bc4-11565f736eda-profile_image-300x300.png",
#             "title": "MrMouton | RANDOMIZED NUZLOCK POKEMON HG"
#         },
#         {
#             "broadcaster_language": "en",
#             "display_name": "mrmouton76",
#             "game_id": "26936",
#             "id": "481027830",
#             "is_live": false,
#             "started_at": "",
#             "tag_ids": [],
# ...
